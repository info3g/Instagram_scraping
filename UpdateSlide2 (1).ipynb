# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.action_chains import ActionChains
import csv
import time,os  
import requests
import urllib.request 

driver = webdriver.Chrome("./chromedriver")
driver.get(url="https://www.instagram.com/accounts/login/")
time.sleep(5)
username = driver.find_element_by_xpath('//input[@name="username"]')
username.click()
time.sleep(5)
username.send_keys("")

password = driver.find_element_by_xpath('//input[@name="password"]')
password.click()
time.sleep(5)
password.send_keys("")
driver.find_element_by_xpath("//button[@type='submit']").click()
time.sleep(5)
not_now=driver.find_element_by_xpath('//div[@class="cmbtv"]')
not_now.click()
time.sleep(5)
not_now=driver.find_element_by_xpath('//button[@class="aOOlW   HoLwm "]')
not_now.click()
time.sleep(5)
searchbox = driver.find_element_by_css_selector("input[placeholder='Search']")
searchbox.clear()
username = "L’Oreal Indonesia"
searchbox.send_keys(username)
time.sleep(5)
search_name=driver.find_element_by_xpath('//a[@class="-qQT3"]')
search_name.click()

comments = []
done=[]
Post_url = []
likess = []

while True:
    last_height = driver.execute_script("return document.body.scrollHeight")
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(6)
    new_height = driver.execute_script("return document.body.scrollHeight")
    ele = driver.find_elements_by_xpath('//div[@class="KL4Bh"]')
    for i in ele:
        try:
            if i not in done:
                done.append(i)
                time.sleep(1)
                action = ActionChains(driver)
                action.move_to_element(i).perform()
                check = driver.find_elements_by_xpath('//li[@class="-V_eO"]/span')
                comment=check[2].text
                lik=check[1].text
                comments.append(comment)
                likess.append(lik)
                print(comment,"yhh!!!!!!!!")
        except:
            pass
        
    post=driver.find_elements_by_xpath('//div[@class="v1Nh3 kIKUG  _bz0w"]')
    for i in post:
        try:
            pst=i.find_element_by_xpath('a').get_attribute('href')
            print(pst)
            if pst not in Post_url:
                Post_url.append(pst)
        except:
            pass
        
    
    if new_height == last_height:
        break
    last_height = new_height


    
    
    
    

viewss = []
dates = []
capstons = []
import time
for i in range(4):
    action = ActionChains(driver)
    action.key_down(Keys.HOME).perform()
postts=driver.find_element_by_xpath("//span[@class='smsjF']").click()
posts=driver.find_element_by_xpath("//div[@class='v1Nh3 kIKUG  _bz0w']").click()
poess=driver.find_element_by_xpath('//span[@class="-nal3 "]')
try:
    s = poess.text.split(' ')[0]
    count = int(s)
    print("try",count)
except:
    try:
        poess.text.split(' ')[0]
        js = s.replace(',' ,'')
        count = int(js)
        print("except",count)
    except:
        count = 500
        pass

for i in range(count):
    time.sleep(2.10)
    try:
        views =driver.find_element_by_xpath('//div[@class="HbPOm _9Ytll"]')
        viewss.append(views.text)
    except:
        viewss.append("null")
    try:
        hello = driver.find_element_by_xpath('//time[@class="_1o9PC Nzb55"]')
        dates.append(hello.text)
    except:
        dates.append("null")
    try:
        caps = driver.find_element_by_xpath('//div[@class="C4VMK"]/span')
        capstons.append(caps.text)
    except:
        capstons.append("null")
        
    try:
        ss = driver.find_element_by_xpath('//a[@class=" _65Bje  coreSpriteRightPaginationArrow"]')
        ss.click()
    except:
        clo = driver.find_element_by_xpath('//div[@class="                     Igw0E     IwRSH      eGOV_         _4EzTm                                                                                  BI4qX            qJPeX            fm1AK   TxciK yiMZG"]')
        clo.click()

maxx=max(len(comments),len(likess),len(viewss),len(capstons),len(dates),len(Post_url))    
maxx

for i in range(1,maxx+1):
    print(i)
    if len(comments) < maxx:
        comments.append("null")
    if len(likess)<maxx:
        likess.append("null")
    if len(viewss)<maxx:
        viewss.append("null")
    if len(capstons)<maxx:
        capstons.append("null")
    if len(dates)<maxx:
        dates.append("null")
    if len(Post_url)<maxx:
        Post_url.append("null")
    
with open('slide2.csv', 'w',newline="",encoding="UTF-8") as csvFile:
    writer = csv.writer(csvFile)
    writer.writerow(['Post Url','Comment', 'Likes','Caption Post','Date of Post'])     
for p,i,j,k,l in zip(Post_url,comments, likess,capstons,dates):
    with open('slide2.csv', 'a+',newline="",encoding="UTF-8") as csvFile:
        writer = csv.writer(csvFile)
        writer.writerow([p,i,j,k,l])
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-8-73b8f8a2dc54> in <module>
#      12
#      13 driver = webdriver.Chrome("./chromedriver")
# ---> 14 driver.get(url="https://www.instagram.com/accounts/login/")
#      15 time.sleep(5)
#      16 username = driver.find_element_by_xpath('//input[@name="username"]')
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# ...
