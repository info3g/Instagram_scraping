# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.options import Options
import csv
import time,os  
import requests
import urllib.request 
# options = Options()
# options.add_argument("--headless") # Runs Chrome in headless mode.
# options.add_argument('--no-sandbox') # # Bypass OS security model
# options.add_argument('start-maximized')
# options.add_argument('disable-infobars')
# options.add_argument("--disable-extensions")
# driver = webdriver.Chrome(chrome_options=options, executable_path='chromedriver.exe')
driver = webdriver.Chrome("./chromedriver.exe")

ig_user = ''
ig_pass = ''


driver.get(url="https://www.instagram.com/accounts/login/")
time.sleep(2)
username = driver.find_element_by_xpath('//input[@name="username"]')
username.click()
time.sleep(2)
username.send_keys(ig_user)

password = driver.find_element_by_xpath('//input[@name="password"]')
password.click()
time.sleep(2)
password.send_keys(ig_pass)

driver.find_element_by_xpath("//button[@type='submit']").click()
time.sleep(3)
not_now=driver.find_element_by_xpath('//div[@class="cmbtv"]')
not_now.click()
time.sleep(3)
not_now=driver.find_element_by_xpath('//button[@class="aOOlW   HoLwm "]')
not_now.click()
time.sleep(2)
searchbox = driver.find_element_by_css_selector("input[placeholder='Search']")
searchbox.clear()
username = ""
searchbox.send_keys(username)
time.sleep(5)
search_name=driver.find_element_by_xpath('//a[@class="-qQT3"]')
search_name.click()
time.sleep(2)
# try:
#     ree=driver.find_element_by_xpath('//div[@class="                     Igw0E   rBNOH        eGOV_     ybXk5    _4EzTm                                                                                                              "]')
#     ree.click()
# except:
#     pass
# time.sleep(2)
# lenOfPage = driver.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
# match=False
# while(match==False):
#     lastCount = lenOfPage
#     time.sleep(3)
#     lenOfPage = driver.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
#     if lastCount==lenOfPage:
#         match=True
#         print('Beak')
#         break
# link = []

# # element = driver.find_elements_by_xpath('//div[@class="Nnq7C weEfm"]')
# # for i in element:
# #     driver.execute_script("return arguments[0].scrollIntoView();", i)
# elements = driver.find_elements_by_xpath('//div[@class="Tjpra"]/a')
# for ie in elements:
#     time.sleep(2)
#     link.append(ie.get_attribute('href'))
# Dates = []
# captionss= []

# time.sleep(5)

# while True:
#     try:
#         post_c=driver.find_element_by_xpath('//div[@class="o53Uu"]')
#         post_c.click()
#     except:
#         pass
#     try:
#         time.sleep(2)
#         Date = driver.find_element_by_xpath('//time[@class="_1o9PC Nzb55"]')
#         Dates.append(Date.text)
#         print(Date.text)
        
#     except:
#         pass
#     try:
#         time.sleep(2)
#         captions = driver.find_element_by_xpath('//div[@class="C4VMK"]/span')
#         captionss.append(captions.text)
# #         print(captions.text)
#     except:
#         pass
#     try:
#         time.sleep(3)
#         ss = driver.find_element_by_xpath('//a[@class=" _65Bje  coreSpriteRightPaginationArrow"]')
#         ss.click()
#     except:
#         print("Breaaaaaakkkkkk")
#         clo = driver.find_element_by_xpath('//div[@class="                     Igw0E     IwRSH      eGOV_         _4EzTm                                                                                  BI4qX            qJPeX            fm1AK   TxciK yiMZG"]')
#         clo.click()
#         break
# time.sleep(2)
# comments = []    
# from bs4 import BeautifulSoup as bs
# lik = []
# datt = driver.page_source
# soup = bs(datt, "html.parser")
# data_all = soup.findAll("div", attrs={"class": "vrLJa"})
# for i in data_all:
#     s = i.find_all("li")
#     for ise in s:
#         lik.append(ise.text)

# # comments = []
# for i in range(1, len(lik), 2):    
#     comments.append(lik[i])  
# likesss = []
# for i in range(0, len(lik), 2):    
#     likesss.append(lik[i])
# time.sleep(2)
# views = [] 
# datst = driver.page_source
# soup = bs(datst, "html.parser")
# data_all = soup.findAll("div", attrs={"class": "o53Uu"})
# for iw in data_all:
#     ss = iw.find_all("span")
#     for w in ss:
#         views.append(w.text)

# with open('loreall.csv', 'w',newline="",encoding="UTF-8") as csvFile:
#     writer = csv.writer(csvFile)
#     writer.writerow(['Post url','View','Comments', 'like','Caption','Date'])     
# for u,p,i,j,k,l in zip(link,views,comments, likesss,captionss,Dates):
#     with open('loreall.csv', 'a+',newline="",encoding="UTF-8") as csvFile:
#         writer = csv.writer(csvFile)
#         writer.writerow([u,p,i,j,k,l])

# %%
lenOfPage = driver.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
match=False
while(match==False):
     try:
        post_c=driver.find_element_by_xpath('//div[@class="o53Uu"]')
        post_c.click()
    except:
        pass
    try:
        time.sleep(2)
        Date = driver.find_element_by_xpath('//time[@class="_1o9PC Nzb55"]')
        Dates.append(Date.text)
        print(Date.text)
        
    except:
        pass
    try:
        time.sleep(2)
        captions = driver.find_element_by_xpath('//div[@class="C4VMK"]/span')
        captionss.append(captions.text)
#         print(captions.text)
    except:
        pass
    try:
        time.sleep(3)
        ss = driver.find_element_by_xpath('//a[@class=" _65Bje  coreSpriteRightPaginationArrow"]')
        ss.click()
    except:
        print("Breaaaaaakkkkkk")
        clo = driver.find_element_by_xpath('//div[@class="                     Igw0E     IwRSH      eGOV_         _4EzTm                                                                                  BI4qX            qJPeX            fm1AK   TxciK yiMZG"]')
        clo.click()
        break
    
    lastCount = lenOfPage
    time.sleep(3)
    lenOfPage = driver.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
    if lastCount==lenOfPage:
        match=True
        print('Beak')
        break
# Out:
# AUGUST 16
# Beak

# %%
comments = []
poess=driver.find_element_by_xpath('//span[@class="-nal3 "]')
try:
    s = poess.text.split(' ')[0]
    count = int(s)
    print("try",count)
except:
    poess.text.split(' ')[0]
    js = s.replace(',' ,'')
    count = int(js)
    print("except",count)
# Out:
# try 439

# %%
for i in range (count):
    try:
        time.sleep(5)
        new_height = driver.execute_script("return document.body.scrollHeight")
        ele = driver.find_elements_by_xpath('//div[@class="KL4Bh"]')
        print(len(ele))
        for i in ele:
            time.sleep(1)
            action = ActionChains(driver)
            action.move_to_element(i).perform()
            check = driver.find_elements_by_xpath('//li[@class="-V_eO"]/span')
            comment=check[2].text
            comments.append(comment)
            print(comment,"yhh!!!!!!!!")

    except:
        pass

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(driver.page_source, 'lxml')

# %%
body = soup.find('body')

# %%
script = body.find('script')

# %%
lenOfPage = driver.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
match=False
while(match==False):
    lastCount = lenOfPage
    time.sleep(3)
    lenOfPage = driver.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
    if lastCount==lenOfPage:
            match=True

# %%
df.text
# Out:
# '<!DOCTYPE html>\n<html lang="en" class="no-js not-logged-in ">\n    <head>\n        <meta charset="utf-8">\n        <meta http-equiv="X-UA-Compatible" content="IE=edge">\n\n        <title>\n                  Page Not Found &bull; Instagram\n                </title>\n\n        \n        <meta name="robots" content="noimageindex, noarchive">\n        <meta name="apple-mobile-web-app-status-bar-style" content="default">\n        <meta name="mobile-web-app-capable" content="yes">\n        <meta name="theme-color" content="#ffffff">\n        <meta id="viewport" name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=1, viewport-fit=cover">\n        <link rel="manifest" href="/data/manifest.json">\n\n        \n        \n        \n\n        <script type="text/javascript">\n        (function() {\n  var docElement = document.documentElement;\n  var classRE = new RegExp(\'(^|\\\\s)no-js(\\\\s|$)\');\n  var className = docElement.className;\n  docElement.cl
# ...

# %%
match=False
while(match==False):
    lenOfPage = driver.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight)")
    
    time.sleep(6)
    lastCount = driver.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
    print(lastCount,lenOfPage)
    source = driver.page_source
    data=BeautifulSoup(source, 'html.parser')
    body = data.find('body')
    script = body.find('script', text=lambda t: t.startswith('window._sharedData'))
    datas=str(script).replace('<script type="text/javascript">window._sharedData = ',"").replace(";</script>","")

    data = json.loads(datas)
    for post in data['entry_data']['ProfilePage'][0]['graphql']['user']['edge_owner_to_timeline_media']['edges']:
        comments = post['node']['edge_media_to_comment']['count']
        print('comments :',comments)
    if lastCount==lenOfPage:
        match=True
    lenOfPage=lastCount
# Out:
# 13603 12319
# comments : 72
# comments : 3
# comments : 5
# comments : 30
# comments : 20
# comments : 6
# comments : 34
# comments : 25
# comments : 144
# comments : 4
# comments : 8
# comments : 529
# 14887 13603
# comments : 72
# comments : 3
# comments : 5
# comments : 30
# comments : 20
# comments : 6
# comments : 34
# comments : 25
# comments : 144
# comments : 4
# comments : 8
# comments : 529
# 14887 14887
# comments : 72
# comments : 3
# comments : 5
# comments : 30
# comments : 20
# comments : 6
# comments : 34
# comments : 25
# comments : 144
# comments : 4
# comments : 8
# comments : 529

# %%
    




source = driver.page_source
data=BeautifulSoup(source, 'html.parser')
body = data.find('body')
script = body.find('script', text=lambda t: t.startswith('window._sharedData'))
datas=str(script).replace('<script type="text/javascript">window._sharedData = ',"").replace(";</script>","")

data = json.loads(datas)
for post in data['entry_data']['ProfilePage'][0]['graphql']['user']['edge_owner_to_timeline_media']['edges']:
    comments = post['node']['edge_media_to_comment']['count']
    print('comments :',comments)
# Out:
# comments : 72
# comments : 3
# comments : 5
# comments : 30
# comments : 20
# comments : 6
# comments : 34
# comments : 25
# comments : 144
# comments : 4
# comments : 8
# comments : 529

# %%
for i in data['entry_data']['ProfilePage'][0]['graphql']['user']['edge_owner_to_timeline_media']['edges']:
    print(i['['node']'])
    print("------------------------")
# Out:
#   File "<ipython-input-233-26618d32ee58>", line 2
#     print(i['['node']'])
#                ^
# SyntaxError: invalid syntax

# %%
datas
# Out:
# '{"config":{"csrf_token":"mLBLwAeE3R0ruXjMotLYLeeyZYY9HVGs","viewer":{"biography":"","business_address_json":null,"business_contact_method":null,"business_email":null,"business_phone_number":null,"can_see_organic_insights":false,"category_name":null,"external_url":null,"fbid":"17841448540744113","full_name":"Rajendra pratap","has_phone_number":false,"has_profile_pic":true,"has_tabbed_inbox":false,"hide_like_and_view_counts":false,"id":"48672906024","is_joined_recently":false,"is_private":false,"is_professional_account":false,"profile_pic_url":"https://instagram.fixc2-1.fna.fbcdn.net/v/t51.2885-19/s150x150/224140182_253191916368773_7726125033831243626_n.jpg?_nc_ht=instagram.fixc2-1.fna.fbcdn.net\\u0026_nc_ohc=WZSY9Ry8XGQAX-9U3Du\\u0026tn=ivYixVupEk1kcHnx\\u0026edm=ABfd0MgBAAAA\\u0026ccb=7-4\\u0026oh=66d35f335614db4217616a6192b5d713\\u0026oe=61304888\\u0026_nc_sid=7bff83","profile_pic_url_hd":"https://instagram.fixc2-1.fna.fbcdn.net/v/t51.2885-19/s320x320/224140182_253191916368773_7726
# ...

# %%
lenOfPage = driver.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
match=False
while(match==False):

    for post in data['entry_data']['ProfilePage'][0]['graphql']['user']['edge_owner_to_timeline_media']['edges']:
        
            comments = post['node']['edge_media_to_comment']['count']
        
#         print('Post on :',datetime.utcfromtimestamp(timestamp).strftime('%Y-%m-%d %H:%M:%S'))
#         print('Liked by :',likedby)
            print('comments :',comments)
        
#         print('caption :',caption)
lenOfPage = driver.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
if lastCount==lenOfPage:
    match=True
# Out:
# comments : 72
# comments : 3
# comments : 5
# comments : 30
# comments : 20
# comments : 6
# comments : 34
# comments : 25
# comments : 144
# comments : 4
# comments : 8
# comments : 529
# comments : 72
# comments : 3
# comments : 5
# comments : 30
# comments : 20
# comments : 6
# comments : 34
# comments : 25
# comments : 144
# comments : 4
# comments : 8
# comments : 529
# comments : 72
# comments : 3
# comments : 5
# comments : 30
# comments : 20
# comments : 6
# comments : 34
# comments : 25
# comments : 144
# comments : 4
# comments : 8
# comments : 529
# comments : 72
# comments : 3
# comments : 5
# comments : 30
# comments : 20
# comments : 6
# comments : 34
# comments : 25
# comments : 144
# comments : 4
# comments : 8
# comments : 529
# comments : 72
# comments : 3
# comments : 5
# comments : 30
# comments : 20
# comments : 6
# comments : 34
# comments : 25
# comments : 144
# comments : 4
# comments : 8
# comments : 529
# comments : 72
# comments : 3
# comments : 5
# ...

# %%
# Out:
# {'config': {'csrf_token': 'mLBLwAeE3R0ruXjMotLYLeeyZYY9HVGs',
#   'viewer': {'biography': '',
#    'business_address_json': None,
#    'business_contact_method': None,
#    'business_email': None,
#    'business_phone_number': None,
#    'can_see_organic_insights': False,
#    'category_name': None,
#    'external_url': None,
#    'fbid': '17841448540744113',
#    'full_name': 'Rajendra pratap',
#    'has_phone_number': False,
#    'has_profile_pic': True,
#    'has_tabbed_inbox': False,
#    'hide_like_and_view_counts': False,
#    'id': '48672906024',
#    'is_joined_recently': False,
#    'is_private': False,
#    'is_professional_account': False,
#    'profile_pic_url': 'https://instagram.fixc2-1.fna.fbcdn.net/v/t51.2885-19/s150x150/224140182_253191916368773_7726125033831243626_n.jpg?_nc_ht=instagram.fixc2-1.fna.fbcdn.net&_nc_ohc=WZSY9Ry8XGQAX-MFRUk&tn=ivYixVupEk1kcHnx&edm=ABfd0MgBAAAA&ccb=7-4&oh=f6862d6c4304eeec5c355c94697a09d8&oe=61304888&_nc_sid=7bff83',
# ...

# %%
res = json.loads(datas)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-128-2b9bed27e37d> in <module>
# ----> 1 res = json.loads(datas)
#
# ~\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     338         end = _w(s, end).end()
#     339         if end != len(s):
# --> 340             raise JSONDecodeError("Extra data", s, end)
#     341         return obj
#     342
#
# JSONDecodeError: Extra data: line 1 column 339138 (char 339137)
