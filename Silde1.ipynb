# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.action_chains import ActionChains
import csv
import time,os  
import requests
import urllib.request 

headerList = ['Posts', 'Followers','Following','Description','Post_url','Reels','IGTV']
with open('herman.csv', 'w',newline='',encoding="UTF-8" ) as csvFile:
    writer = csv.writer(csvFile)
    writer.writerow(headerList) 
driver = webdriver.Chrome("./chromedriver")
driver.get(url="https://www.instagram.com/accounts/login/")
time.sleep(5)
username = driver.find_element_by_xpath('//input[@name="username"]')
username.click()
time.sleep(5)
username.send_keys("")

password = driver.find_element_by_xpath('//input[@name="password"]')
password.click()
time.sleep(5)
password.send_keys("")
driver.find_element_by_xpath("//button[@type='submit']").click()
time.sleep(5)
not_now=driver.find_element_by_xpath('//div[@class="cmbtv"]')
not_now.click()
time.sleep(5)
not_now=driver.find_element_by_xpath('//button[@class="aOOlW   HoLwm "]')
not_now.click()
time.sleep(5)
searchbox = driver.find_element_by_css_selector("input[placeholder='Search']")
searchbox.clear()
username = "thebodyshopindo"
searchbox.send_keys(username)
time.sleep(5)
search_name=driver.find_element_by_xpath('//a[@class="-qQT3"]')
search_name.click()
post_s = []
followings =[]
follower = []
disc = []
time.sleep(5)
driver.maximize_window()
posts=driver.find_element_by_xpath('//span[@class="-nal3 "]')
des=driver.find_element_by_xpath('//h1[@class="rhpdm"]')
followers=driver.find_element_by_xpath('//a[@class="-nal3 "]')
following=driver.find_element_by_xpath('//a[@href="/'+str(username)+'/following/"]')
followings.append(following.text)
follower.append(followers.text)
post_s.append(posts.text)
disc.append(des.text)

images = []
postsss=driver.find_elements_by_xpath('//div[@class="v1Nh3 kIKUG  _bz0w"]')
for i in postsss:
    print(i.find_element_by_xpath('a').get_attribute('href'))
    images.append(i.find_element_by_xpath('a').get_attribute('href'))
time.sleep(2)


driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

while True:
    last_heights = driver.execute_script("return document.body.scrollHeight")
    post=driver.find_elements_by_xpath('//div[@class="v1Nh3 kIKUG  _bz0w"]')
    for i in post:
        try:
            pst=i.find_element_by_xpath('a').get_attribute('href')
            print(pst)
            if pst not in images:
                images.append(pst)
        except:
            pass
    time.sleep(7)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    
    new_heighst = driver.execute_script("return document.body.scrollHeight")
    
    if new_heighst == last_heights:
        break
    last_heights = new_heighst
    
    
for i in range(4):
    action = ActionChains(driver)
    action.key_down(Keys.HOME).perform()
time.sleep(5)
ree=driver.find_element_by_xpath('//div[@class="                     Igw0E   rBNOH        eGOV_     ybXk5    _4EzTm                                                                                                              "]')
ree.click()
last_height = driver.execute_script("return document.body.scrollHeight")
reel = []
print("reellllllllllllllllllllll")

while True:
    last_heights = driver.execute_script("return document.body.scrollHeight")
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(6)
    new_height = driver.execute_script("return document.body.scrollHeight")
    reels=driver.find_elements_by_xpath('//div[@class="Tjpra"]/a')
    
    for i in reels:
        try:
            reel.append(i.get_attribute('href'))
            print(i.get_attribute('href'))
        except:
            pass
    
    if new_height == last_height:
        break
    last_height = new_height
    
    
    
for i in range(4):
    action = ActionChains(driver)
    action.key_down(Keys.HOME).perform()
time.sleep(5)

iggs=[]
ig=driver.find_element_by_xpath('//a[@href="/'+str(username)+'/channel/"]')
ig.click()
print("Tvvvvvvvvvvvvvvvvvvvvvvvvvv")
time.sleep(2)
igs=driver.find_elements_by_xpath('//a[@class="_bz0w"]')
for i in igs:
    iggs.append(i.get_attribute('href'))
    

    
for x in images:
    if len(followings) == len(images) or len(disc) == len(images) or len(follower) == len(images) or len(post) == len(images):
        pass
    else:
        followings.append('')
        disc.append('')
        post.append('')
        follower.append('')
        
maxx=max(len(followings),len(images),len(disc),len(reel),len(follower),len(post),len(iggs))    
maxx

for i in range(1,maxx+1):
    print(i)
    if len(followings) < maxx:
        followings.append("null")
    if len(images)<maxx:
        images.append("null")
    if len(disc)<maxx:
        disc.append("null")
    if len(reel)<maxx:
        reel.append("null")
    if len(follower)<maxx:
        follower.append("null")
    if len(post_s)<maxx:
        post_s.append("null")
    if len(iggs)<maxx:
        iggs.append("null")
        
with open('herman.csv', 'w',newline="",encoding="UTF-8") as csvFile:
    writer = csv.writer(csvFile)
    writer.writerow(['post count', 'follower','followings','disc','images','reel','iggs'])     
        
for i,j,k,l,m,n,o in zip(post_s, follower,followings,disc,images,reel,iggs):
    with open('herman.csv', 'a+',newline="",encoding="UTF-8") as csvFile:
        writer = csv.writer(csvFile)
        writer.writerow([i,j,k,l,m,n,o])
# Out:
# https://www.instagram.com/p/CS8PJnKBpcw/
# https://www.instagram.com/p/CS5rWBxlVPG/
# https://www.instagram.com/p/CS3xZczlMC8/
# https://www.instagram.com/p/CS3EK0TlwpC/
# https://www.instagram.com/p/CS0g8eCFrOO/
# https://www.instagram.com/p/CSx8KhiFiKN/
# https://www.instagram.com/p/CSwFQPXFag9/
# https://www.instagram.com/p/CSsyp3dFTxg/
# https://www.instagram.com/p/CSqHDZmhwyF/
# https://www.instagram.com/p/CSnpl-TFtYD/
# https://www.instagram.com/p/CSlAbhqBKL-/
# https://www.instagram.com/p/CSjLVLJlLCW/
# https://www.instagram.com/p/CSgnmrNFHl2/
# https://www.instagram.com/p/CSdWGqslt6s/
# https://www.instagram.com/p/CSbdPtdFER0/
# https://www.instagram.com/p/CSY66CnFCFu/
# https://www.instagram.com/p/CSVplTBFIjd/
# https://www.instagram.com/p/CSTCPEzlSU2/
# https://www.instagram.com/p/CSRKzellVnN/
# https://www.instagram.com/p/CSN5sXQl7cS/
# https://www.instagram.com/p/CSLV3JKFcif/
# https://www.instagram.com/p/CSJgNrLF1m8/
# https://www.instagram.com/p/CSGKxHBlxf2/
# ...

# %%
for i in range(4):
    action = ActionChains(driver)
    action.key_down(Keys.HOME).perform()
